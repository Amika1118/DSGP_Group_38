# %% [markdown]
# <a href="https://colab.research.google.com/github/Amika1118/DSGP_Group_38/blob/Market-Price-Prediction/preprocessed_retail%2C_fuel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone https://github.com/Amika1118/DSGP_Group_38.git
# %cd DSGP_Group_38
# Out:
# /content
# Cloning into 'DSGP_Group_38'...
# remote: Enumerating objects: 140, done.
# remote: Counting objects: 100% (140/140), done.
# remote: Compressing objects: 100% (113/113), done.
# remote: Total 140 (delta 46), reused 75 (delta 15), pack-reused 0 (from 0)
# Receiving objects: 100% (140/140), 9.69 MiB | 16.42 MiB/s, done.
# Resolving deltas: 100% (46/46), done.
# /content/DSGP_Group_38

# %%
# !git checkout Market-Price-Prediction
# Out:
# Branch 'Market-Price-Prediction' set up to track remote branch 'Market-Price-Prediction' from 'origin'.
# Switched to a new branch 'Market-Price-Prediction'

# %%
# !git config --global user.name "Lasani Layathma"
# !git config --global user.email "lasani.20241357@iit.ac.lk"

# %%
from getpass import getpass
token = getpass("Enter GitHub token: ")
# !git remote set-url origin https://{token}@github.com/Amika1118/DSGP_Group_38.git
# Out:
# Enter GitHub token: ··········

# %%
import pandas as pd
# Load historical weekly retail + fuel data
historical_df = pd.read_csv("/content/retail_fuel_weekly_preprocessed (1).csv")

# %%
# 2. Ensure date is datetime
historical_df['Start_Date'] = pd.to_datetime(historical_df['Start_Date'])

# %%
#Add Data_Type flags
historical_df['Data_Type'] = 'Historical'

# %%
# 4. Save processed historical data
historical_df.to_csv("historical_data_preprocessed.csv", index=False)

print("Historical data shape:", historical_df.shape)
print("Columns:", historical_df.columns.tolist())
# Out:
# Historical data shape: (7784, 62)
# ...

# %%
# !git add .
# !git commit -m "weekly retail, fuel preprocessed dataset"
# Out:
# [Market-Price-Prediction 5eadb38] weekly retail, fuel preprocessed dataset
#  1 file changed, 7785 insertions(+), 7785 deletions(-)

# %%
# !git pull origin Market-Price-Prediction --no-rebase
# Out:
# From https://github.com/Amika1118/DSGP_Group_38
#  * branch            Market-Price-Prediction -> FETCH_HEAD
# Already up to date.

# %%
# !git push origin Market-Price-Prediction
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 34.00 KiB | 328.00 KiB/s, done.
# Total 3 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/Amika1118/DSGP_Group_38.git
#    8a09f6c..5eadb38  Market-Price-Prediction -> Market-Price-Prediction
