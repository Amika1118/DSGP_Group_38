# %%
# STEP 1: Import libraries and define file paths
import pandas as pd
import numpy as np
from pathlib import Path
from datetime import datetime, timedelta

# Define paths (adjust if your folder structure is different)
data_folder = Path("../data/raw")
predictions_file = data_folder / "predictions_2010_2025_for_arosha.csv"
price_file = data_folder / "Amika.xlsx"
exchange_file = data_folder / "USD_LKR Historical Data.csv"
output_file = data_folder / "Vegetable_prices_weekly.csv"

# %%
# STEP 2: Load and prepare climate predictions
# Load the predictions CSV
predictions_df = pd.read_csv(predictions_file)
print(f"Predictions shape: {predictions_df.shape}")

# Convert date column to datetime
predictions_df['date'] = pd.to_datetime(predictions_df['date'])
print(f"Date range: {predictions_df['date'].min()} to {predictions_df['date'].max()}")

# Define function to assign week code (W1..W52) based on fixed weekly intervals
def get_week_code(dt):
    year = dt.year
    for week_num in range(1, 53):
        start = datetime(year, 1, 1) + timedelta(days=(week_num - 1) * 7)
        end = start + timedelta(days=6)
        if start <= dt <= end:
            return f"W{week_num}"
    return None  # Dec 31 falls outside

# Apply the function to create a week_code column
predictions_df['week_code'] = predictions_df['date'].apply(get_week_code)
print("Rows with week code:", predictions_df['week_code'].notna().sum())

# Drop rows without a valid week code (e.g., Dec 31)
df_weekly = predictions_df.dropna(subset=['week_code']).copy()

# Extract year
df_weekly['year'] = df_weekly['date'].dt.year

# Define aggregation for actual_class: flood_risk takes priority, otherwise mode
def weekly_actual_class(series):
    if 'flood_risk' in series.values:
        return 'flood_risk'
    modes = series.mode()
    return modes.iloc[0] if len(modes) > 0 else None

# Group by city, year, and week_code
grouped = df_weekly.groupby(['city', 'year', 'week_code']).agg(
    prob_drought=('prob_drought', 'mean'),
    prob_flood_risk=('prob_flood_risk', 'mean'),
    prob_normal=('prob_normal', 'mean'),
    actual_class=('actual_class', weekly_actual_class)
).reset_index()

print("Weekly climate data shape:", grouped.shape)
print(grouped.head())
# Out:
# Predictions shape: (41321, 6)
# Date range: 2010-01-01 00:00:00 to 2026-02-28 00:00:00
# Rows with week code: 41181
# Weekly climate data shape: (5887, 7)
#       city  year week_code  prob_drought  prob_flood_risk  prob_normal  \
# 0  Badulla  2010        W1      0.000123         0.000708     0.999169
# 1  Badulla  2010       W10      0.000111         0.000708     0.999181
# 2  Badulla  2010       W11      0.000109         0.000708     0.999183
# 3  Badulla  2010       W12      0.000112         0.000710     0.999177
# 4  Badulla  2010       W13      0.000119         0.275926     0.723955
#
#   actual_class
# 0       normal
# 1       normal
# 2       normal
# 3       normal
# 4   flood_risk
# Predictions shape: (41321, 6)
# Date range: 2010-01-01 00:00:00 to 2026-02-28 00:00:00
# Rows with week code: 41181
# Weekly climate data shape: (5887, 7)
#       city  year week_code  prob_drought  prob_flood_risk  prob_normal  \
# ...

# %%
# STEP 3: Load and reshape vegetable price data
# Load the Excel file
price_df = pd.read_excel(price_file)
print("Price data shape:", price_df.shape)

# Identify week columns (W1, W2, ...)
week_cols = [col for col in price_df.columns if col.startswith('W') and col[1:].isdigit()]

# Melt from wide to long format
price_long = price_df.melt(
    id_vars=['Year', 'Item'],
    value_vars=week_cols,
    var_name='week',
    value_name='price'
)
price_long['week'] = price_long['week'].astype(str)
price_long = price_long.sort_values(['Year', 'week', 'Item']).reset_index(drop=True)
print("Reshaped price data (first 5 rows):")
print(price_long.head())
# Out:
# Price data shape: (102, 56)
# Reshaped price data (first 5 rows):
#    Year          Item week  price
# 0  2010  Bitter Gourd   W1   52.4
# 1  2010      Brinjals   W1   60.6
# 2  2010       Cabbage   W1   38.2
# 3  2010        Carrot   W1   66.0
# 4  2010       Pumpkin   W1   20.4
# Price data shape: (102, 56)
# Reshaped price data (first 5 rows):
#    Year          Item week  price
# 0  2010  Bitter Gourd   W1   52.4
# 1  2010      Brinjals   W1   60.6
# 2  2010       Cabbage   W1   38.2
# 3  2010        Carrot   W1   66.0
# 4  2010       Pumpkin   W1   20.4

# %%
# STEP 4: Merge climate data with vegetable prices
# Pivot climate data: each city becomes separate columns for each variable
pivot_climate = grouped.pivot_table(
    index=['year', 'week_code'],
    columns='city',
    values=['prob_drought', 'prob_flood_risk', 'prob_normal', 'actual_class'],
    aggfunc='first'
)
pivot_climate.columns = [f'{city}_{var}' for var, city in pivot_climate.columns]
pivot_climate = pivot_climate.reset_index().rename(columns={'week_code': 'week'})

# Ensure year columns are integers
price_long['year'] = price_long['Year'].astype(int)
pivot_climate['year'] = pivot_climate['year'].astype(int)

# Merge on year and week
combined = pd.merge(
    price_long,
    pivot_climate,
    left_on=['year', 'week'],
    right_on=['year', 'week'],
    how='left'
).drop(columns=['Year'])

# Rename Item to vegetable
combined.rename(columns={'Item': 'vegetable'}, inplace=True)

# Sort by year, week numerically, and vegetable
combined['week_num'] = combined['week'].str.extract(r'(\d+)').astype(int)
combined = combined.sort_values(['year', 'week_num', 'vegetable']).reset_index(drop=True)
combined.drop(columns=['week_num'], inplace=True)

print("Combined climate+price data shape:", combined.shape)
print(combined.head(10))
# Out:
# Combined climate+price data shape: (5406, 32)
#       vegetable week  price  year Badulla_actual_class  \
# 0  Bitter Gourd   W1   52.4  2010               normal
# 1      Brinjals   W1   60.6  2010               normal
# 2       Cabbage   W1   38.2  2010               normal
# 3        Carrot   W1   66.0  2010               normal
# 4       Pumpkin   W1   20.4  2010               normal
# 5      Tomatoes   W1   51.0  2010               normal
# 6  Bitter Gourd   W2   58.6  2010               normal
# 7      Brinjals   W2   51.6  2010               normal
# 8       Cabbage   W2   41.0  2010               normal
# 9        Carrot   W2   68.6  2010               normal
#
#   Hambantota_actual_class Jaffna_actual_class Kurunegala_actual_class  \
# 0                 drought             drought                  normal
# 1                 drought             drought                  normal
# 2                 drought             drought                  normal
# ...

# %%
# STEP 5: Load and aggregate exchange rate data (USD/LKR)
usd_lkr_df = pd.read_csv(exchange_file)

# Clean numeric columns
usd_lkr_df['DollarRate'] = pd.to_numeric(usd_lkr_df['DollarRate'], errors='coerce')
usd_lkr_df['RateChange %'] = usd_lkr_df['RateChange %'].astype(str).str.replace('%', '', regex=False)
usd_lkr_df['RateChange %'] = pd.to_numeric(usd_lkr_df['RateChange %'], errors='coerce')

# Convert Date and extract year/week using same fixed-week method
usd_lkr_df['Date'] = pd.to_datetime(usd_lkr_df['Date'], format='%m/%d/%Y')
usd_lkr_df['year'] = usd_lkr_df['Date'].dt.year
usd_lkr_df['day_of_year'] = usd_lkr_df['Date'].dt.dayofyear
usd_lkr_df['week_num'] = ((usd_lkr_df['day_of_year'] - 1) // 7) + 1
usd_lkr_df['week'] = 'W' + usd_lkr_df['week_num'].astype(str)

# Group by year and week to get weekly averages
weekly_usd = usd_lkr_df.groupby(['year', 'week'], as_index=False).agg(
    USD_LKR_avg=('DollarRate', 'mean'),
    RateChange_avg=('RateChange %', 'mean')
)

print("Weekly USD/LKR data (first 5 rows):")
print(weekly_usd.head())
# Out:
# Weekly USD/LKR data (first 5 rows):
#    year week  USD_LKR_avg  RateChange_avg
# 0  2010   W1       114.40            0.00
# 1  2010  W10       113.98           -0.18
# 2  2010  W11       114.05            0.06
# 3  2010  W12       114.13            0.07
# 4  2010  W13       113.85           -0.25
# Weekly USD/LKR data (first 5 rows):
#    year week  USD_LKR_avg  RateChange_avg
# 0  2010   W1       114.40            0.00
# 1  2010  W10       113.98           -0.18
# 2  2010  W11       114.05            0.06
# 3  2010  W12       114.13            0.07
# 4  2010  W13       113.85           -0.25

# %%
# STEP 6: Merge exchange rates into the combined dataset
# Ensure week columns are strings
combined['week'] = combined['week'].astype(str)
weekly_usd['week'] = weekly_usd['week'].astype(str)

final_df = pd.merge(
    combined,
    weekly_usd,
    on=['year', 'week'],
    how='left'
)

# Reorder columns (optional, for clarity)
cols = ['year', 'week', 'vegetable', 'price'] + \
       [col for col in final_df.columns if col not in ['year', 'week', 'vegetable', 'price']]
final_df = final_df[cols]

print("Final dataset shape:", final_df.shape)
print(final_df.head(10))
# Out:
# Final dataset shape: (5406, 34)
#    year week     vegetable  price Badulla_actual_class  \
# 0  2010   W1  Bitter Gourd   52.4               normal
# 1  2010   W1      Brinjals   60.6               normal
# 2  2010   W1       Cabbage   38.2               normal
# 3  2010   W1        Carrot   66.0               normal
# 4  2010   W1       Pumpkin   20.4               normal
# 5  2010   W1      Tomatoes   51.0               normal
# 6  2010   W2  Bitter Gourd   58.6               normal
# 7  2010   W2      Brinjals   51.6               normal
# 8  2010   W2       Cabbage   41.0               normal
# 9  2010   W2        Carrot   68.6               normal
#
#   Hambantota_actual_class Jaffna_actual_class Kurunegala_actual_class  \
# 0                 drought             drought                  normal
# 1                 drought             drought                  normal
# 2                 drought             drought                  normal
# ...

# %%
# STEP 7: Save the final dataset to CSV
final_df.to_csv(output_file, index=False)
print(f"Final dataset saved to: {output_file}")
# Out:
# Final dataset saved to: ..\data\raw\Vegetable_prices_weekly.csv
# Final dataset saved to: ..\data\raw\Vegetable_prices_weekly.csv
