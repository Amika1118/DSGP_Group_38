# %%
import pandas as pd

# %%
df = pd.read_csv('USDA.csv')

# %%
df
# Out:
#       Unnamed: 0  NDB_No                   Shrt_Desc  Water_(g)  Energ_Kcal  \
# 0              0    1001            BUTTER,WITH SALT      15.87         717
# 1              1    1002      BUTTER,WHIPPED,W/ SALT      16.72         718
# 2              2    1003        BUTTER OIL,ANHYDROUS       0.24         876
# 3              3    1004                 CHEESE,BLUE      42.41         353
# 4              4    1005                CHEESE,BRICK      41.11         371
# ...          ...     ...                         ...        ...         ...
# 8785        8785   83110             MACKEREL,SALTED      43.00         305
# 8786        8786   90240  SCALLOP,(BAY&SEA),CKD,STMD      70.25         111
# 8787        8787   90480                  SYRUP,CANE      26.00         269
# 8788        8788   90560                   SNAIL,RAW      79.20          90
# 8789        8789   93600            TURTLE,GREEN,RAW      78.50          89
#
#       Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  ...  \
# 0            0.85          81.11     2.11            0.06           0.0  ...
# 1            0.49          78.30     1.62            2.87           0.0  ...
# 2            0.28          99.48     0.00            0.00           0.0  ...
# 3           21.40          28.74     5.11            2.34           0.0  ...
# 4           23.24          29.68     3.18            2.79           0.0  ...
# ...           ...            ...      ...             ...           ...  ...
# 8785        18.50          25.10    13.40            0.00           0.0  ...
# 8786        20.54           0.84     2.97            5.41           0.0  ...
# 8787         0.00           0.00     0.86           73.14           0.0  ...
# 8788        16.10           1.40     1.30            2.00           0.0  ...
# 8789        19.80           0.50     1.20            0.00           0.0  ...
#
#       FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)  Cholestrl_(mg)  GmWt_1  \
# 0         51.368       21.021        3.043           215.0    5.00
# 1         45.390       19.874        3.331           225.0    3.80
# 2         61.924       28.732        3.694           256.0   12.80
# 3         18.669        7.778        0.800            75.0   28.35
# 4         18.764        8.598        0.784            94.0  132.00
# ...          ...          ...          ...             ...     ...
# 8785       7.148        8.320        6.210            95.0   80.00
# 8786       0.218        0.082        0.222            41.0   85.00
# 8787       0.000        0.000        0.000             0.0   21.00
# 8788       0.361        0.259        0.252            50.0   85.00
# 8789       0.127        0.088        0.170            50.0   85.00
#
#                               GmWt_Desc1  GmWt_2              GmWt_Desc2  \
# 0             1 pat,  (1" sq, 1/3" high)    14.2                  1 tbsp
# 1             1 pat,  (1" sq, 1/3" high)     9.4                  1 tbsp
# 2                                 1 tbsp   205.0                   1 cup
# 3                                   1 oz    17.0            1 cubic inch
# 4                           1 cup, diced   113.0         1 cup, shredded
# ...                                  ...     ...                     ...
# 8785  1 piece,  (5-1/2" x 1-1/2" x 1/2")    17.0  1 cubic inch, boneless
# 8786                                3 oz     NaN                     NaN
# 8787                           1 serving     NaN                     NaN
# 8788                                3 oz     NaN                     NaN
# 8789                                3 oz     NaN                     NaN
#
#       Refuse_Pct  CLASS
# 0            0.0     10
# 1            0.0     10
# 2            0.0      0
# 3            0.0     10
# 4            0.0     10
# ...          ...    ...
# 8785         0.0      0
# 8786         0.0      0
# 8787         0.0     10
# 8788         0.0      0
# 8789         0.0      0
#
# [8790 rows x 55 columns]

# %%
raw_df = df[df['Shrt_Desc'].str.contains(',RAW', case = False, na = False)]

raw_df
# Out:
#       Unnamed: 0  NDB_No                                          Shrt_Desc  \
# 111          111    1123                                   EGG,WHL,RAW,FRSH
# 112          112    1124                                EGG,WHITE,RAW,FRESH
# 113          113    1125                                  EGG,YOLK,RAW,FRSH
# 114          114    1126                              EGG,YOLK,RAW,FRZ,PAST
# 115          115    1127                      EGG,YOLK,RAW,FRZ,SUGARED,PAST
# ...          ...     ...                                                ...
# 8431        8431   35204  CHOKECHERRIES,RAW,PITTED (NORTHERN PLAINS INDI...
# 8727        8727   43392                                 HEARTS OF PALM,RAW
# 8784        8784   80200                                      FROG LEGS,RAW
# 8788        8788   90560                                          SNAIL,RAW
# 8789        8789   93600                                   TURTLE,GREEN,RAW
#
#       Water_(g)  Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  \
# 111       76.15         143        12.56           9.51     1.06
# 112       87.57          52        10.90           0.17     0.63
# 113       52.31         322        15.86          26.54     1.71
# 114       56.44         296        15.53          25.60     1.62
# 115       51.23         307        13.87          22.82     1.13
# ...         ...         ...          ...            ...      ...
# 8431      60.72         162         3.04           1.69     0.93
# 8727      69.50         115         2.70           0.20     1.99
# 8784      81.90          73        16.40           0.30     1.40
# 8788      79.20          90        16.10           1.40     1.30
# 8789      78.50          89        19.80           0.50     1.20
#
#       Carbohydrt_(g)  Fiber_TD_(g)  ...  FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)  \
# 111             0.72           0.0  ...       3.126        3.658        1.911
# 112             0.73           0.0  ...       0.000        0.000        0.000
# 113             3.59           0.0  ...       9.551       11.738        4.204
# 114             0.81           0.0  ...       8.615        9.956        4.827
# 115            10.95           0.0  ...       7.110        8.885        3.856
# ...              ...           ...  ...         ...          ...          ...
# 8431           33.62          20.0  ...         NaN          NaN          NaN
# 8727           25.61           1.5  ...       0.046        0.005        0.089
# 8784            0.00           0.0  ...       0.076        0.053        0.102
# 8788            2.00           0.0  ...       0.361        0.259        0.252
# 8789            0.00           0.0  ...       0.127        0.088        0.170
#
#       Cholestrl_(mg)  GmWt_1  GmWt_Desc1  GmWt_2     GmWt_Desc2  Refuse_Pct  \
# 111            372.0   50.00     1 large    56.0  1 extra large        12.0
# 112              0.0   33.00     1 large   243.0          1 cup         0.0
# 113           1085.0   17.00     1 large   243.0          1 cup         0.0
# 114            991.0   28.35        1 oz   227.0          .5 lb         0.0
# 115            917.0   28.35        1 oz   227.0          .5 lb         0.0
# ...              ...     ...         ...     ...            ...         ...
# 8431             NaN  154.00       1 cup     NaN            NaN         0.0
# 8727             0.0     NaN         NaN     NaN            NaN         NaN
# 8784            50.0   45.00       1 leg     NaN            NaN         0.0
# 8788            50.0   85.00        3 oz     NaN            NaN         0.0
# 8789            50.0   85.00        3 oz     NaN            NaN         0.0
#
#       CLASS
# 111      10
# 112      11
# 113      10
# 114      10
# 115      10
# ...     ...
# 8431     10
# 8727     10
# 8784      1
# 8788      0
# 8789      0
#
# [1347 rows x 55 columns]

# %%
unique_classes = df['CLASS'].unique()
unique_classes
# Out:
# array([10,  0, 11,  1])

# %%
raw_df = df[df['Shrt_Desc'].str.contains(',RAW', case = False, na = False)]
raw_df
# Out:
#       Unnamed: 0  NDB_No                                          Shrt_Desc  \
# 111          111    1123                                   EGG,WHL,RAW,FRSH
# 112          112    1124                                EGG,WHITE,RAW,FRESH
# 113          113    1125                                  EGG,YOLK,RAW,FRSH
# 114          114    1126                              EGG,YOLK,RAW,FRZ,PAST
# 115          115    1127                      EGG,YOLK,RAW,FRZ,SUGARED,PAST
# ...          ...     ...                                                ...
# 8431        8431   35204  CHOKECHERRIES,RAW,PITTED (NORTHERN PLAINS INDI...
# 8727        8727   43392                                 HEARTS OF PALM,RAW
# 8784        8784   80200                                      FROG LEGS,RAW
# 8788        8788   90560                                          SNAIL,RAW
# 8789        8789   93600                                   TURTLE,GREEN,RAW
#
#       Water_(g)  Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  \
# 111       76.15         143        12.56           9.51     1.06
# 112       87.57          52        10.90           0.17     0.63
# 113       52.31         322        15.86          26.54     1.71
# 114       56.44         296        15.53          25.60     1.62
# 115       51.23         307        13.87          22.82     1.13
# ...         ...         ...          ...            ...      ...
# 8431      60.72         162         3.04           1.69     0.93
# 8727      69.50         115         2.70           0.20     1.99
# 8784      81.90          73        16.40           0.30     1.40
# 8788      79.20          90        16.10           1.40     1.30
# 8789      78.50          89        19.80           0.50     1.20
#
#       Carbohydrt_(g)  Fiber_TD_(g)  ...  FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)  \
# 111             0.72           0.0  ...       3.126        3.658        1.911
# 112             0.73           0.0  ...       0.000        0.000        0.000
# 113             3.59           0.0  ...       9.551       11.738        4.204
# 114             0.81           0.0  ...       8.615        9.956        4.827
# 115            10.95           0.0  ...       7.110        8.885        3.856
# ...              ...           ...  ...         ...          ...          ...
# 8431           33.62          20.0  ...         NaN          NaN          NaN
# 8727           25.61           1.5  ...       0.046        0.005        0.089
# 8784            0.00           0.0  ...       0.076        0.053        0.102
# 8788            2.00           0.0  ...       0.361        0.259        0.252
# 8789            0.00           0.0  ...       0.127        0.088        0.170
#
#       Cholestrl_(mg)  GmWt_1  GmWt_Desc1  GmWt_2     GmWt_Desc2  Refuse_Pct  \
# 111            372.0   50.00     1 large    56.0  1 extra large        12.0
# 112              0.0   33.00     1 large   243.0          1 cup         0.0
# 113           1085.0   17.00     1 large   243.0          1 cup         0.0
# 114            991.0   28.35        1 oz   227.0          .5 lb         0.0
# 115            917.0   28.35        1 oz   227.0          .5 lb         0.0
# ...              ...     ...         ...     ...            ...         ...
# 8431             NaN  154.00       1 cup     NaN            NaN         0.0
# 8727             0.0     NaN         NaN     NaN            NaN         NaN
# 8784            50.0   45.00       1 leg     NaN            NaN         0.0
# 8788            50.0   85.00        3 oz     NaN            NaN         0.0
# 8789            50.0   85.00        3 oz     NaN            NaN         0.0
#
#       CLASS
# 111      10
# 112      11
# 113      10
# 114      10
# 115      10
# ...     ...
# 8431     10
# 8727     10
# 8784      1
# 8788      0
# 8789      0
#
# [1347 rows x 55 columns]

# %%
# filtered_veg_df = raw_df[~raw_df['Shrt_Desc'].str.contains('egg,|pork|chicken|duck|goose|guinea|pheasant|quail|squab|turkey|poultry|ground turkey|ruffed grouse|EMU|ostrich|salsify|seaweed|beef|fish|cod|frog|snail|turtle|deer|buffalo|meat|lamb|steak|mackerel|Acerola|Apples|Apricots|Avocados|Bananas|Blackberries|Breadfruit|Carambola|Carissa|Cherimoya|Cherries|Crabapples|Cranberries|Currants|Custard-apple|Elderberries|Figs|Grapefruit|Grapes|Guavas|Jackfruit|', case = False, na = False)]

# filtered_veg_df

# %%
filtered_veg_df = raw_df[~raw_df['Shrt_Desc'].str.contains('egg,|pork|chicken|duck|goose|guinea|pheasant|quail|squab|turkey|poultry|ground turkey|ruffed grouse|EMU|ostrich|salsify|seaweed|beef|fish|cod|frog|snail|turtle|deer|buffalo|meat|lamb|steak|mackerel|apple|apricot|avocado|banana|blackberr|blueberr|breadfruit|carambola|carissa|cherimoya|cherr|crabapple|cranberr|currant|custard-apple|elderberr|fig|grapefruit|grape|guava|jackfruit|java-plum|jujube|kiwifruit|kumquat|lemon|lime|litch|longan|loquat|mammy-apple|mamey|mango|melon|cantaloupe|casaba|honeydew|mulberr|nectarine|oheloberr|orange|tangerine|papaya|passion-fruit|peach|pear|persimmon|pineapple|pitanga|plantain|plum|pomegranate|prickly pear|pummelo|quince|raspberr|rhubarb|rose-apple|sapodilla|sapote|soursop|strawberr|sugar-apple|sweetsop|tamarind|watermelon|feijoa|durian|abiyuch|rowal|clementine|acorn|cashew|chestnut|ginkgo|macadamia|pistachio|lotus seed|breadfruit seed|breadnut|barley|millet|oat bran|rice|bean|chickpea|garbanzo|cowpea|blackeye|lentil|lupin|mothbean|mung bean|peanut|pigeon pea|soybean|anchovy|bass|burbot|carp|cisco|croaker|cusk|drum|eel|grouper|haddock|halibut|herring|ling|mackerel|mullet|perch|pike|pollock|pompano|roe|roughy|salmon|scup|sea bass|seatrout|shad|shark|sheepshead|smelt|snapper|spot|sturgeon|sucker|trout|tuna|turbot|whiting|yellowtail|crab|lobster|shrimp|abalone|clam|mussel|octopus|oyster|scallop|squid|whelk|veal|bison|goat|whale|caribou|owl|walrus|elk|tofu|heart of palm|beans|Peppers|shiitake|chanterelle|morel|white, portabella|Alfalfa|Corn|beef|pout|chives|soy', case = False, na = False)]

filtered_veg_df
# Out:
#       Unnamed: 0  NDB_No                                      Shrt_Desc  \
# 2120        2120    9002                              ACEROLA JUICE,RAW
# 2379        2379    9311                                    ROSELLE,RAW
# 2815        2815   11003                            AMARANTH LEAVES,RAW
# 2817        2817   11005                                  ARROWHEAD,RAW
# 2819        2819   11007               ARTICHOKES,(GLOBE OR FRENCH),RAW
# ...          ...     ...                                            ...
# 8322        8322   35050                MASHU ROOTS,RAW (ALASKA NATIVE)
# 8369        8369   35138                     SQUASH,INDIAN,RAW (NAVAJO)
# 8419        8419   35192                          AGAVE,RAW (SOUTHWEST)
# 8427        8427   35200  PRAIRIE TURNIPS,RAW (NORTHERN PLAINS INDIANS)
# 8727        8727   43392                             HEARTS OF PALM,RAW
#
#       Water_(g)  Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  \
# 2120      94.30          23         0.40           0.30     0.20
# 2379      86.58          49         0.96           0.64     0.51
# 2815      91.69          23         2.46           0.33     1.50
# 2817      72.48          99         5.33           0.29     1.67
# 2819      84.94          47         3.27           0.15     1.13
# ...         ...         ...          ...            ...      ...
# 8322      67.80         135         5.80           2.40     1.40
# 8369      93.35          26         0.52           0.20     0.29
# 8419      81.83          68         0.52           0.15     1.27
# 8427      60.69         156         2.62           0.36     0.65
# 8727      69.50         115         2.70           0.20     1.99
#
#       Carbohydrt_(g)  Fiber_TD_(g)  ...  FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)  \
# 2120            4.80           0.3  ...       0.068        0.082        0.090
# 2379           11.31           NaN  ...         NaN          NaN          NaN
# 2815            4.02           NaN  ...       0.091        0.076        0.147
# 2817           20.23           NaN  ...         NaN          NaN          NaN
# 2819           10.51           5.4  ...       0.036        0.005        0.064
# ...              ...           ...  ...         ...          ...          ...
# 8322           22.60           NaN  ...         NaN          NaN          NaN
# 8369            5.64           NaN  ...         NaN          NaN          NaN
# 8419           16.23           6.6  ...         NaN          NaN          NaN
# 8427           35.67           8.0  ...         NaN          NaN          NaN
# 8727           25.61           1.5  ...       0.046        0.005        0.089
#
#       Cholestrl_(mg)  GmWt_1              GmWt_Desc1  GmWt_2  \
# 2120             0.0   242.0                   1 cup    30.2
# 2379             0.0    57.0  1 cup,  without refuse     NaN
# 2815             0.0    28.0                   1 cup    14.0
# 2817             0.0    25.0                 1 large    12.0
# 2819             0.0   128.0    1 artichoke,  medium   162.0
# ...              ...     ...                     ...     ...
# 8322             NaN     NaN                     NaN     NaN
# 8369             NaN     NaN                     NaN     NaN
# 8419             0.0     NaN                     NaN     NaN
# 8427             NaN    12.7          1 bulb, peeled     NaN
# 8727             0.0     NaN                     NaN     NaN
#
#                GmWt_Desc2  Refuse_Pct  CLASS
# 2120              1 fl oz         0.0     11
# 2379                  NaN        39.0      1
# 2815               1 leaf         6.0      1
# 2817             1 medium        25.0      0
# 2819  1 artichoke,  large        60.0     11
# ...                   ...         ...    ...
# 8322                  NaN         0.0      0
# 8369                  NaN         0.0     11
# 8419                  NaN         0.0     11
# 8427                  NaN         0.0     10
# 8727                  NaN         NaN     10
#
# [166 rows x 55 columns]

# %%
filtered_veg_df.to_csv('vegetables_USDA.csv')
